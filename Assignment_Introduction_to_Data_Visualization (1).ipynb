# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

df=pd.read_csv('company_sales_data.csv')
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
# Your code here
plt.plot(df['total_profit'],'bo-')
plt.axis([0,12,0,450000])
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
df[['total_profit']].plot(xlabel='Month Number',ylabel='Total_sale')
# Out:
# <AxesSubplot:xlabel='Month Number', ylabel='Total_sale'>

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
df[['facewash','facecream']].plot(kind='bar',figsize=(10,10),xlabel='Month Number',ylabel='sales',title='yearly sale for face wash and face cream')
# Out:
# <AxesSubplot:title={'center':'yearly sale for face wash and face cream'}, xlabel='Month Number', ylabel='sales'>

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %%
# Your code here


df[['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']].plot(kind='line')
# Out:
# <AxesSubplot:>
